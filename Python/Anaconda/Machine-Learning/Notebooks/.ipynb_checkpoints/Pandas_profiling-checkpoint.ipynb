# %%
from ydata_profiling import ProfileReport
import pandas as pd
import seaborn as sns
from tqdm.auto import tqdm

# %%
df=pd.read_csv('../../../Resources/CSVs/train.csv')
profr=ProfileReport(df)
profr.to_file(output_file='out.html')
# Out:
# ...
# Export report to file: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 36.30it/s]
